# %%
import os
import glob
from tqdm.auto import tqdm
data_dir = root_path="../dataset_folder/raw_videos/"

for files in tqdm(glob.glob(os.path.join(data_dir, '*.mp4'))):
    print(files)
# Out:
# 100%|██████████| 7/7 [00:00<00:00, 2455.68it/s]
# ../dataset_folder/raw_videos/002.mp4
# ../dataset_folder/raw_videos/003.mp4
# ../dataset_folder/raw_videos/004.mp4
# ../dataset_folder/raw_videos/006.mp4
# ../dataset_folder/raw_videos/007.mp4
# ../dataset_folder/raw_videos/008.mp4
# ../dataset_folder/raw_videos/010.mp4

# %% [markdown]
# ## PPG Features check

# %%
import pandas as pd

df_in = pd.read_csv("../dataset_folder/ppg_feats.csv")
df_in.head()
# Out:
#    Unnamed: 0  ID  Systolic_peak(x)  Max. Slope(a_ms)  \
# 0           0   2          0.430505          0.236778
# 1           1   3          0.794532          0.436992
# 2           2   4          1.447653          0.796209
# 3           3   7          1.822559          1.002408
# 4           4   8         -0.231244         -0.127184
#
#    Time of Max. Slope(t_ms)  Prev. point DP(a_ip)  Time of a_ip(t_ip)  \
# 0                   0.02200              0.154844               0.080
# 1                   0.02750              0.509334               0.075
# 2                   0.01925              0.885468               0.060
# 3                   0.02200             -0.451647               0.085
# 4                   0.01925              0.416459               0.085
#
#    Diastolic_peak(y)  Dicrotic_notch(z)  Pulse_interval(tpi)  ...  \
# 0           0.163393           0.102019                0.125  ...
# 1           0.532278           0.496873                0.115  ...
# ...

# %%
import pandas as pd
df_ppg = pd.read_csv("../dataset_folder/ppg_signals.csv")
df_ppg.head()
# Out:
#   FileName                                         PPG_Signal
# 0  002.mp4  [-7.45740421e-02 -5.75369718e-02 -3.47941569e-...
# 1  003.mp4  [-1.22463036e-01  1.23920928e-01  2.89547548e-...
# 2  004.mp4  [-1.95776087e-01 -1.03075058e+00 -1.72488790e+...
# 3  007.mp4  [ 1.67735979e-01  2.93958083e-01  3.90294818e-...
# 4  008.mp4  [-1.54965827e-01 -1.49111848e-01 -1.36413165e-...
